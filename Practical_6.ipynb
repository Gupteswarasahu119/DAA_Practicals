# %% [markdown]
# <a href="https://colab.research.google.com/github/Gupteswarasahu119/DAA_Practicals/blob/main/Practical_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def matrix_chain_order(p):
    n = len(p)

    m = [[0 for _ in range(n)] for _ in range(n)]

    for L in range(2, n):
        for i in range(1, n - L + 1):
            j = i + L - 1

            m[i][j] = float('inf')

            for k in range(i, j):
                q = m[i][k] + m[k + 1][j] + p[i - 1] * p[k] * p[j]

                if q < m[i][j]:
                    m[i][j] = q

    return m[1][n - 1]


n = int(input("Enter number of matrices: "))

p = []

print("Enter dimensions:")

for i in range(n + 1):
    p.append(int(input()))

result = matrix_chain_order(p)

print("Minimum number of multiplications =", result)
# Out:
# Enter number of matrices: 3
# Enter dimensions:
# 10
# 30
# 20
# 40
# Minimum number of multiplications = 14000
