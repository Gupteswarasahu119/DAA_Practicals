# %% [markdown]
# <a href="https://colab.research.google.com/github/Gupteswarasahu119/DAA_Practicals/blob/main/Practical_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def min_coins(coins, amount):
    dp = [float('inf')] * (amount + 1)

    dp[0] = 0

    for i in range(1, amount + 1):
        for coin in coins:
            if coin <= i:
                dp[i] = min(dp[i], dp[i - coin] + 1)

    if dp[amount] == float('inf'):
        return -1

    return dp[amount]


n = int(input("Enter number of coin denominations: "))

coins = []

print("Enter coin denominations:")

for i in range(n):
    coins.append(int(input()))

amount = int(input("Enter amount: "))

result = min_coins(coins, amount)

if result == -1:
    print("Change cannot be made.")
else:
    print("Minimum coins required =", result)
# Out:
# Enter number of coin denominations: 3
# Enter coin denominations:
# 1
# 2
# 5
# Enter amount: 11
# Minimum coins required = 3
